# %% [markdown]
# # 05 - Model Evaluation, Explainability & Selection
#
# Comparing Macro F1, Accuracy, Precision, Recall, CV scores, confusion matrix, and feature importances.

# %%
import sys
import pandas as pd
sys.path.append('../')
from src.utils import MODEL_COMPARISON_PATH

# %%
comparison_df = pd.read_csv(MODEL_COMPARISON_PATH)
comparison_df
